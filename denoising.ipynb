# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunchae-L/Denoising/blob/main/denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.parallel import DataParallel
from torch.utils.data import DataLoader, Dataset, TensorDataset

training_dataset_path = '/content/drive/MyDrive/고려대학교/Audio_detection/denoising/Data_Sources/training_dataset1.npy'

# %%
class CustomModel(nn.Module):
    def __init__(self, n_fft, hop_length):
        super(CustomModel, self).__init__()

        self.conv_blocks = nn.Sequential(
            nn.Conv2d(2, 12, kernel_size=13, padding=6), nn.ReLU(), nn.BatchNorm2d(12),
            nn.Conv2d(12, 16, kernel_size=11, padding=5), nn.ReLU(), nn.BatchNorm2d(16),
            nn.Conv2d(16, 20, kernel_size=9, padding=4), nn.ReLU(), nn.BatchNorm2d(20),
            nn.Conv2d(20, 24, kernel_size=7, padding=3), nn.ReLU(), nn.BatchNorm2d(24),
            nn.Conv2d(24, 32, kernel_size=7, padding=3), nn.ReLU(), nn.BatchNorm2d(32),
            nn.Conv2d(32, 24, kernel_size=7, padding=3), nn.ReLU(), nn.BatchNorm2d(24),
            nn.Conv2d(24, 20, kernel_size=9, padding=4), nn.ReLU(), nn.BatchNorm2d(20),
            nn.Conv2d(20, 16, kernel_size=11, padding=5), nn.ReLU(), nn.BatchNorm2d(16),
            nn.Conv2d(16, 12, kernel_size=13, padding=6), nn.ReLU(), nn.BatchNorm2d(12),
        )

        self.additional_conv = nn.Conv2d(12, 2, kernel_size=129, padding=64)

        self.n_fft = n_fft
        self.hop_length = hop_length

    def forward(self, x):
        x_stft = torch.stft(x, n_fft=self.n_fft, hop_length=self.hop_length, return_complex=False)
        x_stft = x_stft.permute(0, 3, 1, 2)

        x_stft = self.conv_blocks(x_stft)
        x_stft = self.additional_conv(x_stft)

        x_real = x_stft[:, 0, :, :]
        x_imag = x_stft[:, 1, :, :]
        x_stft = torch.view_as_complex(torch.stack([x_real, x_imag], dim=-1))

        x_istft = torch.istft(x_stft, n_fft=self.n_fft, hop_length=self.hop_length, return_complex=False, length=len(x[0]))

        return x_istft

# %%
class SNRMetric:
    def __init__(self):
        self.batch_snr_list = []  # 存储每个 batch 中每个样本的 SNR

    def update(self, clean_audio, denoised_audio):
        # 计算每个样本的SNR并存储在列表中
        snr = 10 * torch.log10(torch.sum(clean_audio**2, dim=1) / torch.sum((clean_audio - denoised_audio)**2, dim=1))
        self.batch_snr_list.extend(snr.detach().cpu().numpy())  # 将 Tensor 转换为 NumPy 数组并存储在列表中

    def compute(self):
        # 计算所有样本的平均 SNR
        avg_snr = np.mean(self.batch_snr_list) if len(self.batch_snr_list) > 0 else 0.0

        # 重置 batch_snr_list
        self.batch_snr_list = []

        return avg_snr

# %%
training_dataset = np.load(training_dataset_path)
noisy_data = np.array([item[0] for item in training_dataset])
clean_data = np.array([item[1] for item in training_dataset])
# 转换输入数据为张量
noisy_data = torch.from_numpy(noisy_data)
clean_data = torch.from_numpy(clean_data)

# %%
# STFT参数
n_fft = 1023
hop_length = 500

# 创建数据集和数据加载器
dataset = TensorDataset(noisy_data, clean_data)
batch_size = 40  # 设置批次大小
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# 定义模型、损失函数和优化器
model = CustomModel(n_fft, hop_length)
criterion = nn.MSELoss()  # 使用均方误差损失
optimizer = optim.Adam(model.parameters(), lr=0.001)  # 使用 Adam 优化器

#Use Gpus
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.device_count() > 1:
  print("Using", torch.cuda.device_count(), "GPUs!")
  model = nn.DataParallel(model)
model = model.to(device)

# 在训练循环中使用SNR作为指标
snr_metric = SNRMetric()

# %%
epochs = 1

for epoch in range(epochs):
    model.train()
    for batch_no, (noisy_batch, clean_batch) in enumerate(data_loader):
        optimizer.zero_grad()

        noisy_batch = noisy_batch.to(device)
        clean_batch = clean_batch.to(device)

        # 前向传播
        outputs = model(noisy_batch)
        outputs = outputs.to(device)

        # 计算损失
        loss = criterion(outputs, clean_batch)

        # 计算SNR并更新指标
        snr_metric.update(clean_batch, outputs)

        print(f'Epoch [{epoch+1}/{epochs}], Batch [{batch_no+1}/{len(data_loader)}], Loss: {loss.item()}, SNR: {snr_metric.compute()}')

        # 反向传播和优化
        loss.backward()
        optimizer.step()


# 训练结束后你可以保存模型
torch.save(model.state_dict(), '/content/drive/MyDrive/고려대학교/Audio_detection/denoising/R-CED(10 Covn).pth')

# %%
# Google Drive에 있는 zip 파일의 경로를 설정
zip_file_path = '/content/drive/MyDrive/고려대학교/Audio_detection/data/open.zip'  # zip 파일의 경로로 변경

# 압축 해제할 경로 설정
extract_path = '/content/drive/MyDrive/고려대학교/Audio_detection/data'  # 압축을 해제할 경로로 변경

# 디렉토리 생성 (존재하지 않는 경우)
import os
os.makedirs(extract_path, exist_ok=True)

# 압축 해제
# !unzip {zip_file_path} -d {extract_path}
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGLREVCI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGLXWFHV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGMDZXNH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGNBHIJR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGNYUVFD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOBSHQC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOHGPYC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOJCZPI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOPJRGB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOUDQAW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGOVHKGM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGPAVGYX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGPBFKRL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGPKBYES.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGPLMREG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGPPRAEG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGQYKVKC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGSHBSPQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGSOQIHH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGSVKSRM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGTHJFJE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGTVQNQS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGTZZFQG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGUHCKOU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGUXKMIZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGVFWCTP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGVHVEZO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGVMNLVT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGVOLHDK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGWACYNM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGWFSDRD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGWTPKXW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGWVCIGM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGWWKSWB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGXHENNG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGXOOQIY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGXTZHVO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGYDAFLQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGYWYQWN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGYYBAKV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGYZVQPD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGZBYBMP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGZELJKU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGZGJEAW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGZQITAC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YGZZHOXH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHANNYJS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHAPCBVP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHAQBEIU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHAUGJIT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHAVYCCL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHAYLZQD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHBGCYFW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHBKHXKV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHBLQJAQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHBNAJRR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHCINNHJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHCNKXIN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHCUSQYV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHCYEJSP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHDABMKO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHDVBYOQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHEBVWTQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHEZWUMQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHFGBJMI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHFPYDMB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHFSXEFQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHFTYKHY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHGCOPGR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHGRJFOT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHHDJQVM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHHQCYPU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHHRLMKE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHHUQXWN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHIKCGBC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHIUZDGI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHJLVWIT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHJNDGGY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHJPCPOR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHJPENRG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHKIIPGL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHKQJCGT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHLCZRZY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHLPOLGX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHLTUDEI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHMBKPXC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHMGXBGC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHMNCWIN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHMTAVKZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHMTEQQP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHNQYZOJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHOHOOVQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHOMMWQJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHOQEOEP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHORXAXR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHOUHCDD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHOZSHVG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHPJRGGH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHPTEQPS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHQBQQXW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHRQCOMZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHRZDZHC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHTONUOV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHUNDJGX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHUOEZFE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHURJSWZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHUZAPJZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHVIACOQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHVNSIUH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHWOYJZX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHXDVXJX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHXOMQYG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHYBXNDK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHYHDZXM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHYLZKOU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHYRGYCC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHZHTWRQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YHZVWSTP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIAAFFHB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIBIXJBW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIBJLTCO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIBKISMX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIBOORXC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YICHIPWC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YICXISZH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIDYSUPD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIEBFHRM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIECMXCP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIEHQYBU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIEJIILP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIEKVALX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIERTYSO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIEZVFCE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIFASJZM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIFBWKAF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIFMIOIM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIFPPBRB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIFVWNBZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIGDNTQM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIGHOIBN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIGYIPKX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIHCKBXV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIIDDXAX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIIHSERA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIIQJPGL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIITKAUP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIIZELIU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIJFOFIJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIJNDZAS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIJPIRVQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIJUCBFY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIKCDUUI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIKEBMKC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIKOQGZU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YILBDNCB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YILRCJJT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YILVWHJB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIMSEGUP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIMZRFVZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YINFKEWL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YINKVIBR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YINMEQNL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIOEUMZA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIOIXNIQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIPLLZEV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIPQRRNA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIPRTZGH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIPTRCHU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIPUXRYF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIQICPFA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIQJGKDT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIQNWBJO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIQQGVRB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIRDSVHO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIRPFTXO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIRSZRCZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YISHAYMQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YISHQBTY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YISZWHVL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YITAHRUJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YITCYZIM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YITNWMQP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YITQKMEC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YITRYDCJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIUOSBPV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIVHFWOX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIVIOSOL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIVREJYN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIWCVEUT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIWFPEPV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIWJHABU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIXWCHNR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIYYXEHE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIZCUHXV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIZDWSNA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIZGBWKS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YIZUINXF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJANFVUQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJARNCBN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJAYRMRP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCEHMVV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCFGXHY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCQSGDI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCVRVJG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCYHLFN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJCYOKFM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJDEVZCY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJDHOJZG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJDLUVIK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJEOJHAS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJESXFXN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJFBPRZL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJFSIBCR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJGPTEXU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJGTERZO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJHBMFLG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJHNLUQI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJHTUAAA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJHWCPBJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJIAYNOZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJIFLOUK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJJICMUL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJJPPPSE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJJXUGVE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJKASVEI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJKGZVAQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJKKAYLL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJKWFKOO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJLMZTOE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJMRMYSE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJNKMGQT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOAXLXH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOCSRSI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOIYHLG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOMRFLD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOOFOXJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOUSUHR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOVHDDM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOWDPFG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJOYKHNL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJPDWOFS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJPMEFTO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJPOBARO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJQCIYBU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJQHNJWP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJQNBHML.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJQUVOPA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJQWQVSR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJRGYULH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJRVCHYE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJRXRMNB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJSDFXXC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJSILVNB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJSNWFYX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJSXPGDG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJSZCNSQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJTHMZZX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJTUEGFF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJUOFLGF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJUQIMPU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJWHOIXC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJWMTTYU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJWRWBIS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJWUIHSM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJXBVJKR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJXFHYBS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJXNKCFH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJXTZAGH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJXVXKVR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJYGSEDT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJYRRCCL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJYUJFKA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJYYICQT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJZKWYBA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJZSJHLA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YJZVUUQO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKAISOII.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKBANTQH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKBIVTKK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKBRPVZA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKCWLOXQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKDYUGYH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKDZWPNZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKECYUWR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKEIXXTW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKELIOMD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKENFYEH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKFTUFEF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKGRVYOP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKGTQJZF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKGVLZHE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKHARJSS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKHEUQMW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKIGSTFL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKIKHAIB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKIPIZOS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKIUEJCZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKIYZOHQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKJAHFYR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKJKFZGS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKKDLAPU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKKFQVIF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKKKEAUC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKLARKSY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKMJEQVN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKMJROQY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKMNOAKA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKMOOPRJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKMXNOZM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKNGJFXR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKNPVGRY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKNSSTDX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKNTXJAG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKPGICYJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKPLLCVO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKPLPWRL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKPZLYCO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKQJPBUY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKRUGHVG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKTDBUNQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKTFXHHJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKTSYIOS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKUBCHXD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKUPXEDP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKUWQKCD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVEHBXV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVGXNHL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVOVXYH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVRSOIP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVVPTVC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKVVXDYZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKWHUKUX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKWKJDRC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKWMYLDT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKWUSZVD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKXDGDGD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKXDNXZE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKXWBXCT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKXZZSVS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKYJNIFP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKYNYIYM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKYSUVDM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKZONYTR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKZRLOJG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YKZTHRRR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLABHHIO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLADRNGE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLATKYTL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLAZBPPO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLBJRUNG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLBNWXNT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLBTZDMI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLCJVOVI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLCOLLHT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDCYMLS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDDPAPF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDDUCXW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDHPVST.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDOQXLO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLDREKHQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLEDSNUD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLELGGVJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLERCJJY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLETDDQQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLETDYZK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLEYJVOO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLFGZJDD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLFNMGIE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLFYUEKE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLGKBZOO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLGVSRCA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLHATGFX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLHLJDDJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLHNJACG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLHNOFKT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLIBFKDM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLIUUNCY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLJTLHFX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLJVDNPK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLJYXHCG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLKAWIMH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLKIZIFJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLKUTIVC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLKWUWDH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLLCTJIU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLLVSQAW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLMETWVT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLMIQTTO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLNQRWFN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLOMOIUZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLONXOUF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLOQGYNZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLOUQTMQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLPHLQXH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLPNBVBO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLQYFFKP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLQYUWJD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLRESHYG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLRHWSGD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLSEWBGS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLSZNQNE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLSZTCPX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLSZWNTD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLTBMZYR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLTJHNVV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLTPCXVD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLUGKTAC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLUJCWET.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLUMWHWB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVBGNNH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVBLDQE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVDZSHP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVEWCYT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVHIBYL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVRYNZN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVUNBMH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVUVJQO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVWHNZW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLVXYLUQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLWAYPLJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLWJQFNO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLWLJFEC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLWOFLCW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLWTSZYY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLXHNTMU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLYCITCK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLYMFFXP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLYNQPEU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLYNZGFP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLZEMPXV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLZIJQYL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLZIULQX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLZSHBXX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YLZTUCKY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMAOTQSZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMAPQYBV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMARZWEX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMBFFNZA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMBIXZSZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMBVDTGZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMCEHVBT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMCEOZIE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMCXOIAQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMCYZKEI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDHFFOK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDIKZBW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDJBELZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDODMEQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDRFAMR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMDUHMPI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMECOSDM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMEQPXOP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGAOJTW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGDURVE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGKPMZM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGMPITU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGSSTIG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMGVGMCW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMHGSORD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMHMAYST.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMILBHQM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMINVFCI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMITCQZP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMJSHFJU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMJVZXHO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMKBCNCP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMKPGNXA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMKVQFRF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMLRQPLY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMLSMXMS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMMCXIDI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMMHLJAL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMMHUTBS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMMNGNPU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMMXQSQQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMNHPUWW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMNLTYHV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMNORJQG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMOCMGTF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMOEEOTO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMOGAEEW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMOPNUXI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMOUZRUV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMPAUYPB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMPHGXQI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMPIRUDX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMPLMGLN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMPPEQIR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMQAAYVJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMQAFWKG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMQIYGQA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMQTQNEK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMRGJVZI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMRTKOTG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMRWWPJQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMSIPGGN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMTBJRTT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMTGBQBT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMUDMLPT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMUFEZZQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMVANQNE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMVCKRWD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMVHRXGT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMVIBEYG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMWFLMLF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMXFCSIU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMXZQZCM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMYMSJQI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMYNAZBF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMYTAFRY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMZPJZIN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YMZQZUBI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNAIDSGH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNAOXLFW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNASCPBV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNBDZHXX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNBPEBNK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNBUBIGZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNCEEUGA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNCVJZAQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNDBFABL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNDLWESJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNDPBGAN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNDQHTVQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNDTUUAJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNEIXMJT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNEJSLRC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNEVIJQC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNEZDRMI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNFAIKCB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNFHZCEQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/train/YNFWNQZS.ogg
# ...
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/WYWIFBAB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/WZATYOGV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/WZBJLRXO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XAEAUTRG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XAKJZTWY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XANBGHAP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XBKOUIAQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XBUSHANN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XDGEGNUL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XDKGGNPX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XDYYMBRR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEDSNXGQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEEOFSHS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEGSQIRK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEIVRENJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEJZTGZZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XELHJJSK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XEMXAWEH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XFCOWURM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XFRJIUBF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XFWHASFW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XGDGAIIA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XGHOFSDR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XHGGRLEQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XHOIZFTW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XIBFCQOV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XIUQBCSM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XJQCCIWQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XJQHMDUA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XJQJLGLJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XKZIOIIT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XLAWGDSM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XLEJBRWE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XLXWYAPT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XNTMGSZN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XNVHQWZD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XOGKVQEF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XPCIUBPA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XQMUMCUD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XQTYVNEB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XRBILKXF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XRHESRXU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XSRJRFIT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XSSKPJDE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XTPWFLBB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XTQXTHAH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XUJXSYIO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XUSGPVCP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XVRQIMSK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XWDFCFTN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XWDVISEC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XWKNNHTG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XWPSZUGM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XXQNAMTJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XYDSAUNU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XZEACRDW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XZOCXOTD.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XZRNQAEB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XZRPLXEO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/XZYRQUYF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAFBSDZT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAIFZMQT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAIWFSZI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAJMPHEY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAUSXGLQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAXGXNBW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YAZKRUZX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YBENYCGL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YBQPDAHI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YCBGJALR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YCGEDLUI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YDDCRMYL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YDSDZDSZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YEDWIUCT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YEIJTZNV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YEVGAUSC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YFISKBJU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YFSKFVOA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YFTXJIMF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YGSYXELJ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YIFUNNLP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YJFWMFTH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YJXRGURP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YLJMFWMT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YLKAFKFK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YLUTTQFX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YLVROMCE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YMCDNIPI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YMCTIRLM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YMLNOEYG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YMLXTVAL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YMORIMWY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YNXCJHQS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YNZGWPZH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YNZVEDIE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YOWCEFRW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YOWPYBMM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YPRZCRAE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YQODEXPZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YRBBCABE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YRHTTFYM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YRPRXHRW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YSEHCQSZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YTCNYCWZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YTDSJXFL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YUCVVCOU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YUXLETVR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YVPIVMCT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YWPQBQZR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YXLVSFLN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YZCJEIQK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YZUASZGP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/YZUYXHDS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZACCJWMV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZADCKNAA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZAHHAYYZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZAMUMNOR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZAQCXLRY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZAWVMAED.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZBPNUCRL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZBTHEXIA.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZBUVSMRP.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZBZNGKVY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZCSKRJDI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZDLIURBM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZDNYPFVB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZDXCALDK.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZDZKWULT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZEBIUAJR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZFYZTAUG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZGWAOECT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZGZXEYNV.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZHGOVUQF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZIKAHDQO.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZJEIQIGZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZJFKBZBM.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZJMIEUOH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZJQHKPNS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLDEUKNQ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLDYCTCZ.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLJXHPWB.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLPPVQBR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLVPSUOF.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZLXXYUXC.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZMNXMFZG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZNEUBVFG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZNKETQPG.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZNKNSNKR.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZNVUXGCN.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZQPXXECI.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZQYZMISE.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZROOPFQL.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZSIDQYPY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZUTQKXTH.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZVWEFDBU.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZXUNJOMW.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZXXYQAZT.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZXYKTQGY.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZYDCWUVX.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZYOASADS.ogg
#   inflating: /content/drive/MyDrive/고려대학교/Audio_detection/data/unlabeled_data/ZYUAIDJD.ogg

# %%
import os
import torch
import librosa
import soundfile as sf
from tqdm import tqdm

# CustomModel 클래스 정의가 필요합니다.

# 모델 로드
model_path = '/content/drive/MyDrive/고려대학교/Audio_detection/denoising/R-CED(10 Covn).pth'
model = CustomModel(n_fft=1023, hop_length=500)
model.load_state_dict(torch.load(model_path))
model.eval()

# 디바이스 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 입력 및 출력 폴더 경로 설정
input_folder = '/content/drive/MyDrive/고려대학교/Audio_detection/data/test'
output_folder = '/content/drive/MyDrive/고려대학교/Audio_detection/data/denoise/denoise_test'
os.makedirs(output_folder, exist_ok=True)

# 모든 파일에 대해 노이즈 제거
for filename in tqdm(os.listdir(input_folder)):
    if filename.endswith('.ogg'):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        # 오디오 파일 로드
        y, sr = librosa.load(input_path, sr=None)

        # 데이터 전처리 (STFT)
        y_tensor = torch.from_numpy(y).float().unsqueeze(0).to(device)

        # 노이즈 제거
        with torch.no_grad():
            denoised_output = model(y_tensor)

        # ISTFT로 복원
        denoised_audio = denoised_output.squeeze().cpu().numpy()

        # 결과 저장
        sf.write(output_path, denoised_audio, sr)

print(f'노이즈 제거된 오디오 파일이 {output_folder}에 저장되었습니다.')

# %%
# !git clone https://github.com/yxlu-0102/MP-SENet.git
# Out:
# Cloning into 'MP-SENet'...
# remote: Enumerating objects: 797, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 797 (delta 128), reused 104 (delta 104), pack-reused 656
# Receiving objects: 100% (797/797), 477.72 MiB | 63.89 MiB/s, done.
# Resolving deltas: 100% (203/203), done.
# Updating files: 100% (247/247), done.
